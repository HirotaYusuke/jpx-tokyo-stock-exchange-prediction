# %%
import time
import pandas as pd, numpy as np
import seaborn as sns
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
import datetime as dt

from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import RandomizedSearchCV
from sklearn.model_selection import TimeSeriesSplit, train_test_split
from sklearn.model_selection import StratifiedKFold
from sklearn.preprocessing import OrdinalEncoder

from pycaret.regression import * 
#from pycaret.time_series import TSForecastingExperiment
from pycaret.utils import enable_colab

enable_colab()
# Out:
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
# Colab mode enabled.

# %%
prices = pd.read_pickle('./data/prices.pickle')
X_train = pd.read_pickle('./data/X_train.pickle')
X_val = pd.read_pickle('./data/X_val.pickle')
y_train = pd.read_pickle('./data/y_train.pickle')
y_val = pd.read_pickle('./data/y_val.pickle')
# Out:
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>

# %%
df = pd.read_csv('./data/stock_prices.csv')

df = df.drop("ExpectedDividend", axis=1)
df = df.dropna()
# Out:
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>

# %%
prices.sort_values(['Date', 'RowId']).head(15)
# Out:
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
#                  RowId      Date  SecuritiesCode    Open    High     Low  \
# 937963   20170104_1301  20170104             0.0  2734.0  2755.0  2730.0
# 45860    20170104_1332  20170104             1.0   568.0   576.0   563.0
# 975193   20170104_1333  20170104             2.0  3150.0  3210.0  3140.0
# 712338   20170104_1376  20170104             4.0  1510.0  1550.0  1510.0
# 2044199  20170104_1377  20170104             5.0  3270.0  3350.0  3270.0
# 587777   20170104_1379  20170104             6.0  2105.0  2147.0  2101.0
# 1641075  20170104_1381  20170104             7.0  1950.0  1960.0  1949.0
# 985428   20170104_1407  20170104             8.0   857.0   877.0   851.0
# 2204348  20170104_1414  20170104            10.0  4940.0  5060.0  4935.0
# 1715773  20170104_1417  20170104            11.0  1051.0  1063.0  1048.0
# 1531156  20170104_1419  20170104            12.0   526.0   535.0   526.0
# 77133    20170104_1429  20170104            13.0   418.0   420.0   418.0
# 316147   20170104_1435  20170104            15.0  4165.0  4180.0  4100.0
# 1071035  20170104_1515  20170104            16.0  5610.0  5740.0  5560.0
# 894400   20170104_1518  20170104            17.0  1298.0  1340.0  1298.0
#
#           Close   Volume  AdjustmentFactor  SupervisionFlag    Target  fold  \
# 937963   2742.0    31400               1.0            False  0.000730     2
# 45860     571.0  2798500               1.0            False  0.012324     0
# 975193   3210.0   270800               1.0            False  0.006154     2
# 712338   1550.0    11300               1.0            False  0.011053     1
# 2044199  3330.0   150800               1.0            False  0.003026     4
# 587777   2143.0    77300               1.0            False  0.005169     1
# 1641075  1960.0     1300               1.0            False -0.009326     3
# 985428    866.0   147000               1.0            False -0.003437     2
# 2204348  5050.0   119600               1.0            False  0.000000     4
# 1715773  1053.0   347500               1.0            False -0.007463     3
# 1531156   535.0    51600               1.0            False  0.009259     3
# 77133     418.0    24900               1.0            False  0.007160     0
# 316147   4165.0    95700               1.0            False -0.023641     0
# 1071035  5720.0    25200               1.0            False -0.026502     2
# 894400   1330.0   124300               1.0            False -0.007559     1
#
#               Avg
# 937963   0.000152
# 45860    0.000134
# 975193  -0.000137
# 712338   0.000049
# 2044199  0.000134
# 587777  -0.000034
# 1641075  0.000640
# 985428   0.002518
# 2204348  0.000711
# 1715773  0.000630
# 1531156  0.001528
# 77133    0.000738
# 316147  -0.000254
# 1071035  0.000321
# 894400   0.000286

# %%
prices[prices.duplicated('RowId')]
# Out:
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
# Empty DataFrame
# Columns: [RowId, Date, SecuritiesCode, Open, High, Low, Close, Volume, AdjustmentFactor, SupervisionFlag, Target, fold, Avg]
# Index: []

# %%
df.head(15)
# Out:
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
#             RowId        Date  SecuritiesCode    Open    High     Low   Close  \
# 0   20170104_1301  2017-01-04            1301  2734.0  2755.0  2730.0  2742.0
# 1   20170104_1332  2017-01-04            1332   568.0   576.0   563.0   571.0
# 2   20170104_1333  2017-01-04            1333  3150.0  3210.0  3140.0  3210.0
# 3   20170104_1376  2017-01-04            1376  1510.0  1550.0  1510.0  1550.0
# 4   20170104_1377  2017-01-04            1377  3270.0  3350.0  3270.0  3330.0
# 5   20170104_1379  2017-01-04            1379  2105.0  2147.0  2101.0  2143.0
# 6   20170104_1381  2017-01-04            1381  1950.0  1960.0  1949.0  1960.0
# 7   20170104_1407  2017-01-04            1407   857.0   877.0   851.0   866.0
# 8   20170104_1414  2017-01-04            1414  4940.0  5060.0  4935.0  5050.0
# 9   20170104_1417  2017-01-04            1417  1051.0  1063.0  1048.0  1053.0
# 10  20170104_1419  2017-01-04            1419   526.0   535.0   526.0   535.0
# 11  20170104_1429  2017-01-04            1429   418.0   420.0   418.0   418.0
# 12  20170104_1435  2017-01-04            1435  4165.0  4180.0  4100.0  4165.0
# 13  20170104_1515  2017-01-04            1515  5610.0  5740.0  5560.0  5720.0
# 14  20170104_1518  2017-01-04            1518  1298.0  1340.0  1298.0  1330.0
#
#      Volume  AdjustmentFactor  SupervisionFlag    Target
# 0     31400               1.0            False  0.000730
# 1   2798500               1.0            False  0.012324
# 2    270800               1.0            False  0.006154
# 3     11300               1.0            False  0.011053
# 4    150800               1.0            False  0.003026
# 5     77300               1.0            False  0.005169
# 6      1300               1.0            False -0.009326
# 7    147000               1.0            False -0.003437
# 8    119600               1.0            False  0.000000
# 9    347500               1.0            False -0.007463
# 10    51600               1.0            False  0.009259
# 11    24900               1.0            False  0.007160
# 12    95700               1.0            False -0.023641
# 13    25200               1.0            False -0.026502
# 14   124300               1.0            False -0.007559

# %%
prices = pd.merge(prices.drop('Date', axis=1), df[['RowId','Date']], on=['RowId'], how='left')
prices.sort_values(['Date', 'RowId']).head()
# Out:
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
#                  RowId  SecuritiesCode    Open    High     Low   Close  \
# 937963   20170104_1301             0.0  2734.0  2755.0  2730.0  2742.0
# 45860    20170104_1332             1.0   568.0   576.0   563.0   571.0
# 975193   20170104_1333             2.0  3150.0  3210.0  3140.0  3210.0
# 712338   20170104_1376             4.0  1510.0  1550.0  1510.0  1550.0
# 2044199  20170104_1377             5.0  3270.0  3350.0  3270.0  3330.0
#
#           Volume  AdjustmentFactor  SupervisionFlag    Target  fold       Avg  \
# 937963     31400               1.0            False  0.000730     2  0.000152
# 45860    2798500               1.0            False  0.012324     0  0.000134
# 975193    270800               1.0            False  0.006154     2 -0.000137
# 712338     11300               1.0            False  0.011053     1  0.000049
# 2044199   150800               1.0            False  0.003026     4  0.000134
#
#                Date
# 937963   2017-01-04
# 45860    2017-01-04
# 975193   2017-01-04
# 712338   2017-01-04
# 2044199  2017-01-04

# %%
prices.sort_values(['Date', 'RowId'], inplace=True)
prices.tail()
# Out:
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
#                  RowId  SecuritiesCode    Open    High     Low   Close  \
# 1271123  20211203_9990          1995.0   514.0   528.0   513.0   528.0
# 1215569  20211203_9991          1996.0   782.0   794.0   782.0   794.0
# 331374   20211203_9993          1997.0  1690.0  1690.0  1645.0  1645.0
# 1562101  20211203_9994          1998.0  2388.0  2396.0  2380.0  2389.0
# 74265    20211203_9997          1999.0   690.0   711.0   686.0   696.0
#
#          Volume  AdjustmentFactor  SupervisionFlag    Target  fold       Avg  \
# 1271123   44200               1.0            False  0.034816     2 -0.000549
# 1215569   35900               1.0            False  0.025478     2 -0.000167
# 331374     7200               1.0            False -0.004302     0 -0.000045
# 1562101    6500               1.0            False  0.009098     3  0.000409
# 74265    381100               1.0            False  0.018414     0  0.000201
#
#                Date
# 1271123  2021-12-03
# 1215569  2021-12-03
# 331374   2021-12-03
# 1562101  2021-12-03
# 74265    2021-12-03

# %%
prices['Date'] = pd.to_datetime(prices['Date'])
# Out:
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>

# %%
type(prices['Date'].iloc[0])
# Out:
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
# pandas._libs.tslibs.timestamps.Timestamp

# %%
prices[(prices['Date'] > dt.datetime(2021,10,1)) & (prices['Date'] < dt.datetime(2021,10,29))]
# Out:
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
#                  RowId  SecuritiesCode    Open    High     Low   Close  \
# 824436   20211004_1301             0.0  3010.0  3030.0  2991.0  2998.0
# 912796   20211004_1332             1.0   634.0   638.0   630.0   634.0
# 1916128  20211004_1333             2.0  2634.0  2644.0  2616.0  2644.0
# 728130   20211004_1375             3.0  1520.0  1526.0  1481.0  1496.0
# 302291   20211004_1376             4.0  1529.0  1529.0  1504.0  1517.0
# ...                ...             ...     ...     ...     ...     ...
# 181983   20211028_9990          1995.0   540.0   560.0   538.0   551.0
# 192132   20211028_9991          1996.0   873.0   880.0   867.0   880.0
# 2132137  20211028_9993          1997.0  1701.0  1725.0  1701.0  1725.0
# 1982166  20211028_9994          1998.0  2402.0  2415.0  2376.0  2409.0
# 2201946  20211028_9997          1999.0   798.0   811.0   797.0   805.0
#
#           Volume  AdjustmentFactor  SupervisionFlag    Target  fold       Avg  \
# 824436     10000               1.0            False  0.008811     1  0.000152
# 912796   1147000               1.0            False  0.011327     1  0.000134
# 1916128   131800               1.0            False  0.015751     4 -0.000137
# 728130    244100               1.0            False -0.005373     1 -0.001571
# 302291      3500               1.0            False  0.003497     0  0.000049
# ...          ...               ...              ...       ...   ...       ...
# 181983    234400               1.0            False  0.001815     0 -0.000549
# 192132     16700               1.0            False  0.017442     0 -0.000167
# 2132137     4100               1.0            False -0.003488     4 -0.000045
# 1982166     6500               1.0            False  0.009148     4  0.000409
# 2201946   158800               1.0            False -0.028822     4  0.000201
#
#               Date
# 824436  2021-10-04
# 912796  2021-10-04
# 1916128 2021-10-04
# 728130  2021-10-04
# 302291  2021-10-04
# ...            ...
# 181983  2021-10-28
# 192132  2021-10-28
# 2132137 2021-10-28
# 1982166 2021-10-28
# 2201946 2021-10-28
#
# [37868 rows x 13 columns]

# %%
prices['Day'] = [i.day for i in prices['Date']]
prices['Month'] = [i.month for i in prices['Date']]
prices['Year'] = [i.year for i in prices['Date']]

prices.head()
# Out:
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
#                  RowId  SecuritiesCode    Open    High     Low   Close  \
# 937963   20170104_1301             0.0  2734.0  2755.0  2730.0  2742.0
# 45860    20170104_1332             1.0   568.0   576.0   563.0   571.0
# 975193   20170104_1333             2.0  3150.0  3210.0  3140.0  3210.0
# 712338   20170104_1376             4.0  1510.0  1550.0  1510.0  1550.0
# 2044199  20170104_1377             5.0  3270.0  3350.0  3270.0  3330.0
#
#           Volume  AdjustmentFactor  SupervisionFlag    Target  fold       Avg  \
# 937963     31400               1.0            False  0.000730     2  0.000152
# 45860    2798500               1.0            False  0.012324     0  0.000134
# 975193    270800               1.0            False  0.006154     2 -0.000137
# 712338     11300               1.0            False  0.011053     1  0.000049
# 2044199   150800               1.0            False  0.003026     4  0.000134
#
#               Date  Day  Month  Year
# 937963  2017-01-04    4      1  2017
# 45860   2017-01-04    4      1  2017
# 975193  2017-01-04    4      1  2017
# 712338  2017-01-04    4      1  2017
# 2044199 2017-01-04    4      1  2017

# %%
prices['Series'] = np.arange(1,len(prices)+1)

prices = prices[['Series', 'Day', 'Year', 'Month', 'Target']]

prices.head()
# Out:
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
#          Series  Day  Year  Month    Target
# 937963        1    4  2017      1  0.000730
# 45860         2    4  2017      1  0.012324
# 975193        3    4  2017      1  0.006154
# 712338        4    4  2017      1  0.011053
# 2044199       5    4  2017      1  0.003026

# %%
prices.tail()
# Out:
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
#           Series  Day  Year  Month    Target
# 1271123  2324919    3  2021     12  0.034816
# 1215569  2324920    3  2021     12  0.025478
# 331374   2324921    3  2021     12 -0.004302
# 1562101  2324922    3  2021     12  0.009098
# 74265    2324923    3  2021     12  0.018414

# %%
train, val = train_test_split(prices, shuffle=False,test_size=0.2)
train.shape, val.shape
# Out:
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
# ((1859938, 5), (464985, 5))

# %%
reg = setup(
    data = prices,
    #train_size = 0.7, #学習データと検証データを7:3に分割
    target = 'Target',
    fold_strategy = 'timeseries',
    numeric_features = ['Series', 'Day', 'Year', 'Month'], # 欠損値を平均値で補完する
    transform_target = True,
    fold = 5,
    #log_data=True, # 学習データと検証データのCSVへの出力
    #silent = True, # 型推定の確認をスキップ
    session_id = 123
    )
# Out:
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>
# <style type="text/css">
# #T_5e3d2_row7_col1, #T_5e3d2_row11_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_5e3d2">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5e3d2_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_5e3d2_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5e3d2_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5e3d2_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_5e3d2_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_5e3d2_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_5e3d2_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_5e3d2_row1_col1" class="data row1 col1" >Target</td>
#     </tr>
#     <tr>
#       <th id="T_5e3d2_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_5e3d2_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_5e3d2_row2_col1" class="data row2 col1" >regression</td>
#     </tr>
#     <tr>
#       <th id="T_5e3d2_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_5e3d2_row3_col0" class="data row3 col0" >Data shape</td>
#       <td id="T_5e3d2_row3_col1" class="data row3 col1" >(2324923, 5)</td>
#     </tr>
#     <tr>
#       <th id="T_5e3d2_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_5e3d2_row4_col0" class="data row4 col0" >Train data shape</td>
#       <td id="T_5e3d2_row4_col1" class="data row4 col1" >(1627446, 5)</td>
#     </tr>
#     <tr>
#       <th id="T_5e3d2_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_5e3d2_row5_col0" class="data row5 col0" >Test data shape</td>
#       <td id="T_5e3d2_row5_col1" class="data row5 col1" >(697477, 5)</td>
#     </tr>
#     <tr>
#       <th id="T_5e3d2_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_5e3d2_row6_col0" class="data row6 col0" >Numeric features</td>
#       <td id="T_5e3d2_row6_col1" class="data row6 col1" >4</td>
#     </tr>
#     <tr>
#       <th id="T_5e3d2_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_5e3d2_row7_col0" class="data row7 col0" >Preprocess</td>
#       <td id="T_5e3d2_row7_col1" class="data row7 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_5e3d2_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_5e3d2_row8_col0" class="data row8 col0" >Imputation type</td>
#       <td id="T_5e3d2_row8_col1" class="data row8 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_5e3d2_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_5e3d2_row9_col0" class="data row9 col0" >Numeric imputation</td>
#       <td id="T_5e3d2_row9_col1" class="data row9 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_5e3d2_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_5e3d2_row10_col0" class="data row10 col0" >Categorical imputation</td>
#       <td id="T_5e3d2_row10_col1" class="data row10 col1" >constant</td>
#     </tr>
#     <tr>
#       <th id="T_5e3d2_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_5e3d2_row11_col0" class="data row11 col0" >Transform target</td>
#       <td id="T_5e3d2_row11_col1" class="data row11 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_5e3d2_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_5e3d2_row12_col0" class="data row12 col0" >Transform target method</td>
#       <td id="T_5e3d2_row12_col1" class="data row12 col1" >box-cox</td>
#     </tr>
#     <tr>
#       <th id="T_5e3d2_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_5e3d2_row13_col0" class="data row13 col0" >Fold Generator</td>
#       <td id="T_5e3d2_row13_col1" class="data row13 col1" >TimeSeriesSplit</td>
#     </tr>
#     <tr>
#       <th id="T_5e3d2_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_5e3d2_row14_col0" class="data row14 col0" >Fold Number</td>
#       <td id="T_5e3d2_row14_col1" class="data row14 col1" >5</td>
#     </tr>
#     <tr>
#       <th id="T_5e3d2_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_5e3d2_row15_col0" class="data row15 col0" >CPU Jobs</td>
#       <td id="T_5e3d2_row15_col1" class="data row15 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_5e3d2_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_5e3d2_row16_col0" class="data row16 col0" >Log Experiment</td>
#       <td id="T_5e3d2_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_5e3d2_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_5e3d2_row17_col0" class="data row17 col0" >Experiment Name</td>
#       <td id="T_5e3d2_row17_col1" class="data row17 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_5e3d2_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_5e3d2_row18_col0" class="data row18 col0" >USI</td>
#       <td id="T_5e3d2_row18_col1" class="data row18 col1" >cf96</td>
#     </tr>
#   </tbody>
# </table>

# %%
""" # Sharpe Ratio 関数
import math

def shaperatio(y_true, y_pred):
    df = .copy()
    df["daily_ret"] = DF["close"].pct_change() #株価終値の前日との変化率を計算する。
    ret_ave=np.mean(df["daily_ret"])
    vol_sp = df["daily_ret"].std() 
    return  math.sqrt(256)*ret_ave/vol_sp """

# %%
""" from pycaret.classification import add_metric
add_metric('sharperatio', 'Sharpe Ratio', shaperatio, greater_is_better = True) """

# %%
""" best = compare_models(sort = 'MAE') """
# Out:
# <style type="text/css">
# </style>
# <table id="T_3147b">
#   <thead>
#   </thead>
#   <tbody>
#   </tbody>
# </table>

# %%
""" best """
